# %% [markdown]
# ***Import files.***

# %%
import pandas as pd
df_books = pd.read_csv('/home/jann/Platzi/DataScience/CourseNumpyAndPandasBasic/stages_TDF (1).csv', sep =',')
df_books
# Out:
#      Stage        Date  Distance             Origin  \
# 0        1  2017-07-01      14.0         Düsseldorf
# 1        2  2017-07-02     203.5         Düsseldorf
# 2        3  2017-07-03     212.5           Verviers
# 3        4  2017-07-04     207.5  Mondorf-les-Bains
# 4        5  2017-07-05     160.5             Vittel
# ...    ...         ...       ...                ...
# 2231     2  1903-07-05     374.0               Lyon
# 2232     3  1903-07-08     423.0          Marseille
# 2233     4  1903-07-12     268.0           Toulouse
# 2234     5  1903-07-13     425.0           Bordeaux
# 2235     6  1903-07-18     471.0             Nantes
#
#                        Destination                    Type  \
# 0                       Düsseldorf   Individual time trial
# 1                            Liège              Flat stage
# 2                           Longwy   Medium mountain stage
# 3                           Vittel              Flat stage
# ...

# %% [markdown]
# __Filtrado con loc y iloc__

# %%
df_books[0:5]
# Out:
#   Stage        Date  Distance             Origin  \
# 0     1  2017-07-01      14.0         Düsseldorf
# 1     2  2017-07-02     203.5         Düsseldorf
# 2     3  2017-07-03     212.5           Verviers
# 3     4  2017-07-04     207.5  Mondorf-les-Bains
# 4     5  2017-07-05     160.5             Vittel
#
#                     Destination                   Type          Winner  \
# 0                    Düsseldorf  Individual time trial  Geraint Thomas
# 1                         Liège             Flat stage   Marcel Kittel
# 2                        Longwy  Medium mountain stage     Peter Sagan
# 3                        Vittel             Flat stage   Arnaud Démare
# 4  La Planche des Belles Filles  Medium mountain stage       Fabio Aru
#
#   Winner_Country
# 0            GBR
# 1            GER
# 2            SVK
# 3            FRA
# 4            ITA

# %%
df_books[['Date','Winner']]
# Out:
#             Date                 Winner
# 0     2017-07-01         Geraint Thomas
# 1     2017-07-02          Marcel Kittel
# 2     2017-07-03            Peter Sagan
# 3     2017-07-04          Arnaud Démare
# 4     2017-07-05              Fabio Aru
# ...          ...                    ...
# 2231  1903-07-05  Hippolyte Aucouturier
# 2232  1903-07-08  Hippolyte Aucouturier
# 2233  1903-07-12         Charles Laeser
# 2234  1903-07-13          Maurice Garin
# 2235  1903-07-18          Maurice Garin
#
# [2236 rows x 2 columns]

# %% [markdown]
# __loc__

# %%
df_books.loc[:]
# Out:
#      Stage        Date  Distance             Origin  \
# 0        1  2017-07-01      14.0         Düsseldorf
# 1        2  2017-07-02     203.5         Düsseldorf
# 2        3  2017-07-03     212.5           Verviers
# 3        4  2017-07-04     207.5  Mondorf-les-Bains
# 4        5  2017-07-05     160.5             Vittel
# ...    ...         ...       ...                ...
# 2231     2  1903-07-05     374.0               Lyon
# 2232     3  1903-07-08     423.0          Marseille
# 2233     4  1903-07-12     268.0           Toulouse
# 2234     5  1903-07-13     425.0           Bordeaux
# 2235     6  1903-07-18     471.0             Nantes
#
#                        Destination                    Type  \
# 0                       Düsseldorf   Individual time trial
# 1                            Liège              Flat stage
# 2                           Longwy   Medium mountain stage
# 3                           Vittel              Flat stage
# ...

# %%
df_books.loc[0:4]
# Out:
#   Stage        Date  Distance             Origin  \
# 0     1  2017-07-01      14.0         Düsseldorf
# 1     2  2017-07-02     203.5         Düsseldorf
# 2     3  2017-07-03     212.5           Verviers
# 3     4  2017-07-04     207.5  Mondorf-les-Bains
# 4     5  2017-07-05     160.5             Vittel
#
#                     Destination                   Type          Winner  \
# 0                    Düsseldorf  Individual time trial  Geraint Thomas
# 1                         Liège             Flat stage   Marcel Kittel
# 2                        Longwy  Medium mountain stage     Peter Sagan
# 3                        Vittel             Flat stage   Arnaud Démare
# 4  La Planche des Belles Filles  Medium mountain stage       Fabio Aru
#
#   Winner_Country
# 0            GBR
# 1            GER
# 2            SVK
# 3            FRA
# 4            ITA

# %%
df_books.loc[0:4,['Date','Winner']]
# Out:
#          Date          Winner
# 0  2017-07-01  Geraint Thomas
# 1  2017-07-02   Marcel Kittel
# 2  2017-07-03     Peter Sagan
# 3  2017-07-04   Arnaud Démare
# 4  2017-07-05       Fabio Aru

# %%
df_books.loc[:,['Distance']] * 10
# Out:
#       Distance
# 0        140.0
# 1       2035.0
# 2       2125.0
# 3       2075.0
# 4       1605.0
# ...        ...
# 2231    3740.0
# 2232    4230.0
# 2233    2680.0
# 2234    4250.0
# 2235    4710.0
#
# [2236 rows x 1 columns]

# %% [markdown]
# ##  __ILOC__

# %%
df_books.iloc[:]
# Out:
#      Stage        Date  Distance             Origin  \
# 0        1  2017-07-01      14.0         Düsseldorf
# 1        2  2017-07-02     203.5         Düsseldorf
# 2        3  2017-07-03     212.5           Verviers
# 3        4  2017-07-04     207.5  Mondorf-les-Bains
# 4        5  2017-07-05     160.5             Vittel
# ...    ...         ...       ...                ...
# 2231     2  1903-07-05     374.0               Lyon
# 2232     3  1903-07-08     423.0          Marseille
# 2233     4  1903-07-12     268.0           Toulouse
# 2234     5  1903-07-13     425.0           Bordeaux
# 2235     6  1903-07-18     471.0             Nantes
#
#                        Destination                    Type  \
# 0                       Düsseldorf   Individual time trial
# 1                            Liège              Flat stage
# 2                           Longwy   Medium mountain stage
# 3                           Vittel              Flat stage
# ...

# %%
df_books.iloc[:2,2:]
# Out:
#    Distance      Origin Destination                   Type          Winner  \
# 0      14.0  Düsseldorf  Düsseldorf  Individual time trial  Geraint Thomas
# 1     203.5  Düsseldorf       Liège             Flat stage   Marcel Kittel
#
#   Winner_Country
# 0            GBR
# 1            GER

# %%
df_books.iloc[:2,2] * 2
# Out:
# 0     28.0
# 1    407.0
# Name: Distance, dtype: float64
