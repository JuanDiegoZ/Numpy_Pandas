# %% [markdown]
# Principal fuction in pandas

# %%
import pandas as pd
df_ciclyng = pd.read_csv("/home/jann/Platzi/DataScience/CourseNumpyAndPandasBasic/stages_TDF (1).csv")

# %%
df_ciclyng.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2236 entries, 0 to 2235
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Stage           2236 non-null   object
#  1   Date            2236 non-null   object
#  2   Distance        2236 non-null   float64
#  3   Origin          2236 non-null   object
#  4   Destination     2236 non-null   object
#  5   Type            2236 non-null   object
#  6   Winner          2236 non-null   object
#  7   Winner_Country  2184 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 139.9+ KB

# %%
df_ciclyng.describe()
# Out:
#           Distance
# count  2236.000000
# mean    196.782994
# std      90.176385
# min       1.000000
# 25%     156.000000
# 50%     199.000000
# 75%     236.000000
# max     482.000000

# %%
df_ciclyng.tail(5)
# Out:
#      Stage        Date  Distance     Origin Destination  \
# 2231     2  1903-07-05     374.0       Lyon   Marseille
# 2232     3  1903-07-08     423.0  Marseille    Toulouse
# 2233     4  1903-07-12     268.0   Toulouse    Bordeaux
# 2234     5  1903-07-13     425.0   Bordeaux      Nantes
# 2235     6  1903-07-18     471.0     Nantes       Paris
#
#                         Type                 Winner Winner_Country
# 2231  Stage with mountain(s)  Hippolyte Aucouturier            FRA
# 2232             Plain stage  Hippolyte Aucouturier            FRA
# 2233             Plain stage         Charles Laeser            SUI
# 2234             Plain stage          Maurice Garin            FRA
# 2235             Plain stage          Maurice Garin            FRA

# %%
df_ciclyng.memory_usage(deep = True)
# Out:
# Index                128
# Stage             131119
# Date              149812
# Distance           17888
# Origin            152976
# Destination       153101
# Type              161252
# Winner            170230
# Winner_Country    132764
# dtype: int64

# %%
df_ciclyng['Winner_Country'].value_counts()
# Out:
# FRA                691
# BEL                460
# ITA                262
# NED                157
# ESP                125
# GER                 71
# LUX                 70
# GBR                 67
# SUI                 57
# USA                 38
# AUS                 29
# DEN                 18
# NOR                 17
# COL                 16
# FRG                 14
# POR                 12
# SVK                  9
# IRE                  9
# UZB                  7
# RUS                  7
# URS                  6
# POL                  5
# AUT                  4
# EST                  4
# UKR                  4
# KAZ                  4
# c("FRA", "FRA")      3
# CZE                  3
# IRL                  2
# LAT                  2
# MEX                  2
# GDR                  1
# c("BEL", "GER")      1
# CAN                  1
# SLO                  1
# BRA                  1
# SWE                  1
# RSA                  1
# LTU                  1
# c("BEL", "BEL")      1
# ...

# %% [markdown]
# ## __Delete repeat date.__

# %%
df_ciclyng.drop_duplicates()
# Out:
#      Stage        Date  Distance             Origin  \
# 0        1  2017-07-01      14.0         Düsseldorf
# 1        2  2017-07-02     203.5         Düsseldorf
# 2        3  2017-07-03     212.5           Verviers
# 3        4  2017-07-04     207.5  Mondorf-les-Bains
# 4        5  2017-07-05     160.5             Vittel
# ...    ...         ...       ...                ...
# 2231     2  1903-07-05     374.0               Lyon
# 2232     3  1903-07-08     423.0          Marseille
# 2233     4  1903-07-12     268.0           Toulouse
# 2234     5  1903-07-13     425.0           Bordeaux
# 2235     6  1903-07-18     471.0             Nantes
#
#                        Destination                    Type  \
# 0                       Düsseldorf   Individual time trial
# 1                            Liège              Flat stage
# 2                           Longwy   Medium mountain stage
# 3                           Vittel              Flat stage
# ...

# %% [markdown]
# ## __Ordenate Values.__

# %%
df_ciclyng.sort_values("Distance",ascending=False)
# Out:
#      Stage        Date  Distance                Origin           Destination  \
# 2042     5  1921-07-04     482.0   Les Sables-d'Olonne               Bayonne
# 2027     5  1922-07-03     482.0   Les Sables d'Olonne               Bayonne
# 2057     5  1920-07-05     482.0   Les Sables d'Olonne               Bayonne
# 2012     5  1923-07-02     482.0   Les Sables d'Olonne               Bayonne
# 2072     5  1919-07-07     482.0   Les Sables-d'Olonne               Bayonne
# ...    ...         ...       ...                   ...                   ...
# 885      P  1977-06-30       5.0             Fleurance             Fleurance
# 667      P  1986-07-04       4.6  Boulogne-Billancourt  Boulogne-Billancourt
# 894     7b  1977-07-08       4.0                Angers                Angers
# 918     5a  1976-06-29       4.0                Leuven                Leuven
# 618      P  1988-07-03       1.0             Pornichet              La Baule
#
# ...

# %%
df_ciclyng.sort_values('Winner')
# Out:
#     Stage        Date  Distance            Origin       Destination  \
# 441    20  1997-07-26      63.0  Disneyland Paris  Disneyland Paris
# 597     1  1989-07-02     135.5   Luxembourg City   Luxembourg City
# 644     3  1987-07-04     219.0         Karlsruhe         Stuttgart
# 622     4  1988-07-06     158.0           Le Mans            Évreux
# 794     8  1981-07-03     182.0         Rochefort            Nantes
# ..    ...         ...       ...               ...               ...
# 202    14  2008-07-19     194.5             Nîmes   Digne-les-Bains
# 236     5  2006-07-06     225.0          Beauvais              Caen
# 317     2  2002-07-08     181.0   Luxembourg City       Saarbrücken
# 267    16  2005-07-19     180.5           Mourenx               Pau
# 416    17  1998-07-29     149.0       Albertville     Aix-les-Bains
#
#                        Type           Winner Winner_Country
# 441   Individual time trial    Abraham Olano            ESP
# ...

# %%
df_ciclyng.describe()
# Out:
#           Distance
# count  2236.000000
# mean    196.782994
# std      90.176385
# min       1.000000
# 25%     156.000000
# 50%     199.000000
# 75%     236.000000
# max     482.000000

# %%
df_ciclyng[df_ciclyng["Winner_Country"].isin(["COL"])]
# Out:
#     Stage        Date  Distance             Origin          Destination  \
# 8       9  2017-07-09     181.5             Nantua             Chambéry
# 35     15  2016-07-17     160.0    Bourg-en-Bresse                Culoz
# 103    20  2013-07-20     125.0             Annecy               Semnoz
# 219     9  2007-07-17     159.5        Val-d'Isère             Briançon
# 324     9  2002-07-15      52.0           Lanester              Lorient
# 330    15  2002-07-23     226.5  Vaison-la-Romaine       Les Deux Alpes
# 348    12  2001-07-20     166.5          Perpignan  Plateau de Bonascre
# 370    14  2000-07-15     249.5         Draguignan             Briançon
# 454    11  1996-07-11     202.0                Gap              Valence
# 503    17  1994-07-20     149.0  Le Bourg-d'Oisans          Val Thorens
# 523    15  1993-07-19     231.5          Perpignan                  Pal
# 629    11  1988-07-13     232.0           Besançon              Morzine
# ...
