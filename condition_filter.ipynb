# %%
import pandas as pd
df_cyling = pd.read_csv('/home/jann/Platzi/DataScience/CourseNumpyAndPandasBasic/stages_TDF (1).csv')
df_cyling[:5]
# Out:
#   Stage        Date  Distance             Origin  \
# 0     1  2017-07-01      14.0         Düsseldorf
# 1     2  2017-07-02     203.5         Düsseldorf
# 2     3  2017-07-03     212.5           Verviers
# 3     4  2017-07-04     207.5  Mondorf-les-Bains
# 4     5  2017-07-05     160.5             Vittel
#
#                     Destination                   Type          Winner  \
# 0                    Düsseldorf  Individual time trial  Geraint Thomas
# 1                         Liège             Flat stage   Marcel Kittel
# 2                        Longwy  Medium mountain stage     Peter Sagan
# 3                        Vittel             Flat stage   Arnaud Démare
# 4  La Planche des Belles Filles  Medium mountain stage       Fabio Aru
#
#   Winner_Country
# 0            GBR
# 1            GER
# 2            SVK
# 3            FRA
# 4            ITA

# %% [markdown]
# ## __Mayores a cierto valor.__

# %%
mayor_150km = df_cyling["Distance"] > 150
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 2231     True
# 2232     True
# 2233     True
# 2234     True
# 2235     True
# Name: Distance, Length: 2236, dtype: bool

# %%
df_cyling[mayor_150km]
# Out:
#      Stage        Date  Distance             Origin  \
# 1        2  2017-07-02     203.5         Düsseldorf
# 2        3  2017-07-03     212.5           Verviers
# 3        4  2017-07-04     207.5  Mondorf-les-Bains
# 4        5  2017-07-05     160.5             Vittel
# 5        6  2017-07-06     216.0             Vesoul
# ...    ...         ...       ...                ...
# 2231     2  1903-07-05     374.0               Lyon
# 2232     3  1903-07-08     423.0          Marseille
# 2233     4  1903-07-12     268.0           Toulouse
# 2234     5  1903-07-13     425.0           Bordeaux
# 2235     6  1903-07-18     471.0             Nantes
#
#                        Destination                    Type  \
# 1                            Liège              Flat stage
# 2                           Longwy   Medium mountain stage
# 3                           Vittel              Flat stage
# 4     La Planche des Belles Filles   Medium mountain stage
# ...

# %%
col_nationality = df_cyling["Winner_Country"] ==  "COL"
df_cyling[col_nationality & (df_cyling["Distance"] > 200) ]
# Out:
#     Stage        Date  Distance             Origin      Destination  \
# 330    15  2002-07-23     226.5  Vaison-la-Romaine   Les Deux Alpes
# 370    14  2000-07-15     249.5         Draguignan         Briançon
# 454    11  1996-07-11     202.0                Gap          Valence
# 523    15  1993-07-19     231.5          Perpignan              Pal
# 629    11  1988-07-13     232.0           Besançon          Morzine
# 703    12  1985-07-10     269.0    Morzine Avoriaz  Lans-en-Vercors
#
#                        Type               Winner Winner_Country
# 330             Hilly stage      Santiago Botero            COL
# 370  Stage with mountain(s)      Santiago Botero            COL
# 454             Hilly stage  José Jaime Gonzalez            COL
# 523  Stage with mountain(s)      Oliverio Rincón            COL
# 629  Stage with mountain(s)          Fabio Parra            COL
# 703  Stage with mountain(s)          Fabio Parra            COL
