# %%
import pandas as pd
import  numpy as np
df_books = pd.read_csv('/home/jann/Platzi/DataScience/CourseNumpyAndPandasBasic/stages_TDF (1).csv', sep =',')
df_books
# Out:
#      Stage        Date  Distance             Origin  \
# 0        1  2017-07-01      14.0         Düsseldorf
# 1        2  2017-07-02     203.5         Düsseldorf
# 2        3  2017-07-03     212.5           Verviers
# 3        4  2017-07-04     207.5  Mondorf-les-Bains
# 4        5  2017-07-05     160.5             Vittel
# ...    ...         ...       ...                ...
# 2231     2  1903-07-05     374.0               Lyon
# 2232     3  1903-07-08     423.0          Marseille
# 2233     4  1903-07-12     268.0           Toulouse
# 2234     5  1903-07-13     425.0           Bordeaux
# 2235     6  1903-07-18     471.0             Nantes
#
#                        Destination                    Type  \
# 0                       Düsseldorf   Individual time trial
# 1                            Liège              Flat stage
# 2                           Longwy   Medium mountain stage
# 3                           Vittel              Flat stage
# ...

# %% [markdown]
# ##__Drop Columns__

# %%
#DELETE OF THE VIEW
df_books.drop("Stage", axis=1)
# Out:
#             Date  Distance             Origin                   Destination  \
# 0     2017-07-01      14.0         Düsseldorf                    Düsseldorf
# 1     2017-07-02     203.5         Düsseldorf                         Liège
# 2     2017-07-03     212.5           Verviers                        Longwy
# 3     2017-07-04     207.5  Mondorf-les-Bains                        Vittel
# 4     2017-07-05     160.5             Vittel  La Planche des Belles Filles
# ...          ...       ...                ...                           ...
# 2231  1903-07-05     374.0               Lyon                     Marseille
# 2232  1903-07-08     423.0          Marseille                      Toulouse
# 2233  1903-07-12     268.0           Toulouse                      Bordeaux
# 2234  1903-07-13     425.0           Bordeaux                        Nantes
# 2235  1903-07-18     471.0             Nantes                         Paris
#
# ...

# %%
#Delete of the Data frame
df_books.drop("Stage", axis=1,inplace=True)
#Or Use python to delete.
del df_books["Date"]

# %%
df_books
# Out:
#       Distance             Origin                   Destination  \
# 0         14.0         Düsseldorf                    Düsseldorf
# 1        203.5         Düsseldorf                         Liège
# 2        212.5           Verviers                        Longwy
# 3        207.5  Mondorf-les-Bains                        Vittel
# 4        160.5             Vittel  La Planche des Belles Filles
# ...        ...                ...                           ...
# 2231     374.0               Lyon                     Marseille
# 2232     423.0          Marseille                      Toulouse
# 2233     268.0           Toulouse                      Bordeaux
# 2234     425.0           Bordeaux                        Nantes
# 2235     471.0             Nantes                         Paris
#
#                         Type                 Winner Winner_Country
# 0      Individual time trial         Geraint Thomas            GBR
# ...

# %% [markdown]
# ##__Drop rows__

# %%
#Drop column 3 of the view.
df_books.drop(3,axis = 0).head(10)
#Using range
df_books.drop(range(4,7),axis = 0).head(10)
# Out:
#     Distance             Origin          Destination                   Type  \
# 0       14.0         Düsseldorf           Düsseldorf  Individual time trial
# 1      203.5         Düsseldorf                Liège             Flat stage
# 2      212.5           Verviers               Longwy  Medium mountain stage
# 3      207.5  Mondorf-les-Bains               Vittel             Flat stage
# 7      187.5               Dole  Station des Rousses  Medium mountain stage
# 8      181.5             Nantua             Chambéry    High mountain stage
# 9      178.0          Périgueux             Bergerac             Flat stage
# 10     203.5              Eymet                  Pau             Flat stage
# 11     214.5                Pau           Peyragudes    High mountain stage
# 12     101.0       Saint-Girons                 Foix    High mountain stage
#
#               Winner Winner_Country
# 0     Geraint Thomas            GBR
# 1      Marcel Kittel            GER
# ...

# %% [markdown]
# ## __add Columns__

# %%
df_books['Nueva_Columna'] = np.nan
df_books
# Out:
#      Stage        Date  Distance             Origin  \
# 0        1  2017-07-01      14.0         Düsseldorf
# 1        2  2017-07-02     203.5         Düsseldorf
# 2        3  2017-07-03     212.5           Verviers
# 3        4  2017-07-04     207.5  Mondorf-les-Bains
# 4        5  2017-07-05     160.5             Vittel
# ...    ...         ...       ...                ...
# 2231     2  1903-07-05     374.0               Lyon
# 2232     3  1903-07-08     423.0          Marseille
# 2233     4  1903-07-12     268.0           Toulouse
# 2234     5  1903-07-13     425.0           Bordeaux
# 2235     6  1903-07-18     471.0             Nantes
#
#                        Destination                    Type  \
# 0                       Düsseldorf   Individual time trial
# 1                            Liège              Flat stage
# 2                           Longwy   Medium mountain stage
# 3                           Vittel              Flat stage
# ...

# %% [markdown]
# ## __Add rows__

# %%
#append method in df_books.
df_books.append(df_books)
# Out:
# /tmp/ipykernel_9123/123084459.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_books.append(df_books)
#      Stage        Date  Distance             Origin  \
# 0        1  2017-07-01      14.0         Düsseldorf
# 1        2  2017-07-02     203.5         Düsseldorf
# 2        3  2017-07-03     212.5           Verviers
# 3        4  2017-07-04     207.5  Mondorf-les-Bains
# 4        5  2017-07-05     160.5             Vittel
# ...    ...         ...       ...                ...
# 2231     2  1903-07-05     374.0               Lyon
# 2232     3  1903-07-08     423.0          Marseille
# 2233     4  1903-07-12     268.0           Toulouse
# 2234     5  1903-07-13     425.0           Bordeaux
# 2235     6  1903-07-18     471.0             Nantes
#
#                        Destination                    Type  \
# 0                       Düsseldorf   Individual time trial
# ...
